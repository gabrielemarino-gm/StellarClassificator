# %%
import tkinter as tk
import pickle
import pandas as pd

# PyCharm
# file = './model.pkl'

# VS Code
file = './model.pkl'

# Crea la finestra principale
root = tk.Tk()
root.wm_title('Stellar Classification')
root.geometry("350x500+50+50")


label_u = tk.Label(root, text = "u:")
label_g = tk.Label(root, text = "g:")
label_r = tk.Label(root, text = "r:")
label_i = tk.Label(root, text = "i:")
label_z = tk.Label(root, text = "z:")
label_run = tk.Label(root, text = "run:")
label_specobjid = tk.Label(root, text = "specobjid:")
label_redshift = tk.Label(root, text = "redshift:")
label_plate = tk.Label(root, text = "plate:")
label_mjd = tk.Label(root, text = "mjd:")

entry_u = tk.Entry(root)
entry_g = tk.Entry(root)
entry_r = tk.Entry(root)
entry_i = tk.Entry(root)
entry_z = tk.Entry(root)
entry_run = tk.Entry(root)
entry_specobjid = tk.Entry(root)
entry_redshift = tk.Entry(root)
entry_plate = tk.Entry(root)
entry_mjd = tk.Entry(root)

# Posiziona la etichetta e il pulsante nella finestra
label_u.grid(row=1, column=0, pady=10, padx=10, sticky="e")
entry_u.grid(row=1, column=1)

label_g.grid(row=2, column=0, pady=10, padx=10, sticky="e")
entry_g.grid(row=2, column=1)

label_r.grid(row=3, column=0, pady=10, padx=10, sticky="e")
entry_r.grid(row=3, column=1)

label_i.grid(row=4, column=0, pady=10, padx=10, sticky="e")
entry_i.grid(row=4, column=1)

label_z.grid(row=5, column=0, pady=10, padx=10, sticky="e")
entry_z.grid(row=5, column=1)

label_run.grid(row=6, column=0, pady=10, padx=10)
entry_run.grid(row=6, column=1)

label_specobjid.grid(row=7, column=0, pady=10, padx=10)
entry_specobjid.grid(row=7, column=1)

label_redshift.grid(row=8, column=0, pady=10, padx=10)
entry_redshift.grid(row=8, column=1)

label_plate.grid(row=9, column=0, pady=10, padx=10)
entry_plate.grid(row=9, column=1)

label_mjd.grid(row=10, column=0, pady=10, padx=10)
entry_mjd.grid(row=10, column=1)

label_res = tk.Label(root)
label_res.grid(row=12, column=1, pady=10, padx=10)

def start():
    # Apri il file in modalità di lettura binaria
    with open(file, 'rb') as f:
        # Carica il modello dal file
        classifier = pickle.load(f)

    u = float(entry_u.get())
    g = float(entry_g.get())
    r = float(entry_r.get())
    i = float(entry_i.get())
    z = float(entry_z.get())
    run = float(entry_run.get())
    specobjid = float(entry_specobjid.get())
    redshift = float(entry_redshift.get())
    plate = float(entry_plate.get())
    mjd = float(entry_mjd.get())

    df = pd.DataFrame(
    {
        "u": [u],
        "g": [g],
        "r": [r],
        "i": [i],
        "z": [z],
        "run": [run],
        "specobjid": [specobjid],
        "redshift": [redshift],
        "plate": [plate],
        "mjd": [mjd]
    })

    y_pred = classifier.predict(df)

    if y_pred == "GALAXY":
        label_res.config(text="GALAXY")
    elif y_pred == "STAR":
        label_res.config(text="STAR")
    else:
        label_res.config(text="QUASAR")


def reset():
    entry_g.delete(0, tk.END)
    entry_r.delete(0, tk.END)
    entry_i.delete(0, tk.END)
    entry_z.delete(0, tk.END)
    entry_specobjid.delete(0, tk.END)
    entry_redshift.delete(0, tk.END)
    entry_plate.delete(0, tk.END)
    entry_mjd.delete(0, tk.END)
    label_res.config(text="")

# Crea un pulsante
buttonReset = tk.Button(root, text = "Reset", command=reset)
buttonStart = tk.Button(root, text = "Start", command=start)

buttonReset.grid(row=11, column=1, pady=10, padx=10, sticky="sw")
buttonStart.grid(row=11, column=1, pady=10, padx=10, sticky="se")


# Avvia il ciclo di eventi di Tkinter
root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/Users/gabriele/opt/anaconda3/envs/DMML/lib/python3.10/tkinter/__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "/var/folders/l_/l62k0nts6mv_tz0g9jwbv9z80000gn/T/ipykernel_25588/2667211121.py", line 104, in start
#     y_pred = classifier.predict(df)
#   File "/Users/gabriele/opt/anaconda3/envs/DMML/lib/python3.10/site-packages/sklearn/ensemble/_forest.py", line 821, in predict
#     proba = self.predict_proba(X)
#   File "/Users/gabriele/opt/anaconda3/envs/DMML/lib/python3.10/site-packages/sklearn/ensemble/_forest.py", line 863, in predict_proba
#     X = self._validate_X_predict(X)
#   File "/Users/gabriele/opt/anaconda3/envs/DMML/lib/python3.10/site-packages/sklearn/ensemble/_forest.py", line 603, in _validate_X_predict
#     X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#   File "/Users/gabriele/opt/anaconda3/envs/DMML/lib/python3.10/site-packages/sklearn/base.py", line 518, in _validate_data
#     self._check_feature_names(X, reset=reset)
#   File "/Users/gabriele/opt/anaconda3/envs/DMML/lib/python3.10/site-packages/sklearn/base.py", line 451, in _check_feature_names
#     raise ValueError(message)
# ValueError: The feature names should match those that were passed during fit.
# Feature names seen at fit time, yet now missing:
# - camcol
# - dec
# - fiberid
# - field
# - ra
# Canceled future for execute_request message before replies were done
# Si è verificato un arresto anomalo del kernel durante l'esecuzione del codice nella cella attiva o in una cella precedente. Esaminare il codice nelle celle per identificare una possibile causa dell'errore. Per altre informazioni, fare clic su <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a>. Per altri dettagli, vedere Jupyter <a href='command:jupyter.viewOutput'>log</a>.
